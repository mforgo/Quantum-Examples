# %% [markdown]
# # Pauli-X Gate
#
# This program simulates a Pauli-X gate, also known as the quantum NOT gate.
# Author: Michal Forgó
# Time: 12.8.2025
# Note: Ensure you have installed the requirements.txt or environment.yml before running this notebook.

# %% [markdown]
# ## 1. Introduction
# The Pauli-X Gate, also known as the quantum NOT gate, is a fundamental quantum gate that flips the state of a qubit. It changes the state $$|0\rangle$$ to $$|1\rangle$$ and vice versa. This document explains the logic, significance, and representation of the Pauli-X Gate, providing a clear understanding of its role in quantum circuits and its implementation from first principles.
#
# The matrix for this gate is:
#
# $$
# \begin{bmatrix}
# 0 & 1 \\
# 1 & 0 \\
# \end{bmatrix}
# $$
#
# This matrix represents the operation of swapping the amplitudes of the $$|0\rangle$$ and $$|1\rangle$$ states, effectively flipping the qubit state. The Pauli-X gate is crucial in quantum algorithms and circuits as it acts as a bit-flip operator analogous to the classical NOT gate.

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector

qreg_q = QuantumRegister(1, 'q')
creg_c = ClassicalRegister(1, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

plot_bloch_multivector(Statevector(circuit), title="Initial State")

# %%
circuit.x(qreg_q[0])
plot_bloch_multivector(Statevector(circuit), title="After Pauli-X Gate")

# %%
Statevector(circuit).draw("latex")
# Out:
# $$ |1\rangle$$

# %%
circuit.measure(qreg_q[0], creg_c[0])

sim = AerSimulator(shots=5000)
result = sim.run(circuit).result()

print(result.get_counts(circuit))
# Out:
# {'1': 5000}

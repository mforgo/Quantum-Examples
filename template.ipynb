# %% [markdown]
# # **Title**
#
# This notebook is part of a project . This project was sponsored by ... .
#
# <div align="center">
#   <img src="logo_sponsor1.png" alt="Sponsor 1" width="150"/>
#   <img src="logo_sponsor2.png" alt="Sponsor 2" width="150"/>
#   <img src="logo_sponsor3.png" alt="Sponsor 3" width="150"/>
# </div>
#
# This algorithm is Laboris ea laborum duis cupidatat officia aute ad sunt sint tempor laboris do officia. Dolore do proident ut commodo. Adipisicing nisi laborum elit occaecat anim.
#
# ### Prerequisites & Required Knowledge
#
# Before diving into this notebook, make sure you're familiar with:
# - **QFT** → [QFT](./Circuits/QFT.ipynb)
#
# > **Difficulty Level**: [Beginner/Intermediate/Advanced]
# > **Estimated Time**: [X hours]

# %% [markdown]
# ## 1. Explanation & Theory
#
# ### 1.1 Concrete Example - The Problem We're Solving
#
# Let's start with a practical example that illustrates why we need [algorithm name]:
#
# **Scenario**: [Describe a concrete, relatable problem]
#
# **Classical Approach**:
#
# ### 1.2 Mathematical Foundation
#
# The mathematics behind this algorithm ...
#
# **Primary Transformation**
# $$
# |\psi\rangle = \frac{1}{\sqrt{N}} \sum_{j=0}^{N-1} e^{\tfrac{2\pi \mathrm{i} j k}{N}} |k\rangle
# $$
#
# **Matrix Representation**
# $$
# U = \begin{pmatrix}
# u_{00} & u_{01} & \cdots & u_{0n} \\
# u_{10} & u_{11} & \cdots & u_{1n} \\
# \vdots & \vdots & \ddots & \vdots \\
# u_{n0} & u_{n1} & \cdots & u_{nn}
# \end{pmatrix}
# $$
#
# **Probability Amplitudes**
# $$
# P(|k\rangle) = |\langle k | \psi \rangle|^2
# $$
#
# ## 2. Algorithm Step-by-Step Breakdown
#
# ### 2.1 Initialization
# Firsly we need that all qubits are in the state $$| - \rangle$$

# %%
from qiskit import QuantumCircuit
import math

N = 32  # Number of states, must be a power of 2
n_qubits = int(math.log2(N))
qc = QuantumCircuit(n_qubits)

initial_state = '-' * n_qubits  # Initial state as a string of '0's
qc.initialize(initial_state, range(n_qubits))

# %%
from qiskit.visualization import plot_histogram

# Example measurement results (counts)
counts = {'00': 10, '01': 5, '10': 2, '11': 33}

# Plot histogram
plot_histogram(counts, title='Measurement Results Histogram')

# %%
from qiskit.visualization import plot_bloch_vector

# Example Bloch vector (state on Bloch sphere)
bloch_vector = [0.5, 0.5, 0.707] 

# Plot Bloch sphere vector
plot_bloch_vector(bloch_vector, title='Qubit on Bloch Sphere')

# %%
from qiskit.visualization import plot_bloch_multivector
from qiskit.quantum_info import Statevector
from qiskit import QuantumCircuit

qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0, 1)

# Get the statevector for the circuit
state = Statevector.from_instruction(qc)

# Plot Bloch spheres for each qubit in the statevector
plot_bloch_multivector(state, title='Multi-Qubit Bloch Spheres')

# %% [markdown]
# ## 3. Summary
#
# In this notebook, we explored [algorithm name] and learned Et irure mollit ad ut Lorem anim non. Esse nisi nulla pariatur id proident amet laboris adipisicing. Dolor occaecat consectetur est occaecat in proident nostrud cillum sunt. Ullamco deserunt aliquip duis irure elit Lorem enim elit occaecat et amet incididunt.
#
# **Key Takeaway**: [One sentence summary of the most important learning]
#
# ### 3.1 Follow-Up Notebooks
#
# Ready to dive deeper? Continue your quantum computing journey with these related notebooks:
#
# - **[QFT]** → [QFT](./Circuits/QFT.ipynb)
#
#
# ### 3.2 Citations
# - Aaronscott, S. (2024). On the Quantum Complexity of Explaining Quantum Complexity. Journal of Theoretical Overthinking, 17(3), 314–1592.
#
# ### 3.2 Get Involved
#
# #### **Found an Issue?**
# - Report bugs or suggest improvements: [GitHub Issues](https://github.com/mforgo/Quantum-Examples/issues)
# - Contribute to the codebase: [Contributing guidelines link](https://github.com/mforgo/Quantum-Examples/blob/master/README.md)
#
# #### **Contact & Feedback**
# ...
#
# > *Last Updated: [Date] | Version: [Version Number] | License: [License Type]*
